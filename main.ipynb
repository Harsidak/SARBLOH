# %% [markdown]
# # SARBLOH — driver
#
# The single entry point for development runs. This notebook **orchestrates**; it does not
# implement. All logic lives in `sarbloh/`. If a cell here grows past a few lines, it belongs in a module.
#
# Order below mirrors the loop in `CLAUDE.md` §3.

# %% [markdown]
# ## 0. Setup
#
# Imports, paths, and the config for this session. Record the git SHA — it goes in the ledger.

# %%
# imports, repo root on sys.path, git sha

# %% [markdown]
# ## 1. Environment
#
# `Arcade` in OFFLINE mode against `eval/real_games/`. Same interface as COMPETITION — do not
# build a second loop for development.

# %%
# arcade = Arcade(operation_mode=..., environments_dir='eval/real_games')

# %% [markdown]
# ## 2. Agent
#
# Construct from `sarbloh.agent`, wired to `surat`, `memory`, `worldmodel`, `parkh`, `jugat`.

# %% [markdown]
# ## 3. Run
#
# One environment first. Only scale to the split once a single environment completes end to end.

# %% [markdown]
# ## 4. Score
#
# `eval.official_score` is the only scorer whose output enters the ledger. Name the split.

# %% [markdown]
# ## 5. Diagnostics
#
# The numbers the memory thesis is actually tested on: actions to first certified model,
# re-derivation events, wall-clock per environment. RHAE alone does not tell you whether the memory change worked.

# %% [markdown]
# ## 6. Ledger
#
# Append to `history/ledger.jsonl` **here**, in the run. Not afterwards.
# See `planning/MISTAKES.md` for what happened the last time this was deferred.
